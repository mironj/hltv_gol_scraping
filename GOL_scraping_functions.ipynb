# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
import country_converter as coco

# %%
def send_request(url):
    url = url 
    headers = {'User-Agent': 'Mozilla/5.0'}  
    response = requests.get(url, headers=headers)
    
    return(response)

# %%
def get_lol_team_id(season):
    """Returns a list of IDs (strings) of teams that played in the given season and played at least 40 games. 
    Includes major and minor regions, all tiers and tournaments."""
    
    url = f'https://gol.gg/teams/list/season-S{season}/split-ALL/tournament-ALL/'
    
    page = send_request(url)

    soup = BeautifulSoup(page.content, "html.parser")
    elements = soup.find_all('a')
    IDs = []
    for element in elements:
        line = str(element)
        IDs.append(line)

    pattern = re.compile(r"/team-stats/(.*?)\/split-ALL")
    IDs = [', '.join(pattern.findall(s)) for s in IDs]
    IDs = [value for value in IDs if value != ""]

    elements = soup.find_all('td', class_="text-center")
    games = []
    for element in elements:
        line = str(element)
        games.append(line)    
    games = games[2::29]
    pattern = re.compile(r">(.*?)\<")
    games = [', '.join(pattern.findall(s)) for s in games]
    games = [int(item) for item in games]
    IDs = [ID for ID, game in zip(IDs, games) if game > 40]
    
    return IDs

# %%
def get_lol_team_info(team_season_id):
    """Returns a dataframe containing info on 5 players with the most games played on that team in that season:
    1. Season, winrate, games played by a team
    2. Player names
    3. Player KDA, VSPM, games played
    4. Player country of origin"""
    
    url = f'https://gol.gg/teams/team-stats/{team_season_id}/split-ALL/tournament-ALL/'
    
    page = send_request(url)
    
    if page.status_code == 200:
    
        soup = BeautifulSoup(page.content, "html.parser")

        elements = soup.find_all('div', class_="col-12 col-sm-6 rowbreak pb-4")
        lines = []
        for element in elements:
            element_lines = element.get_text("\n", strip=True).split("\n")
            lines.extend([line for line in element_lines if line.strip()])
        team_stats = "\n".join(lines)

        elements = soup.select('a[href*="player-stats"]')
        player_names = []
        for element in elements:
            element_lines = element.get_text("\n", strip=True).split("\n")
            player_names.extend([line for line in element_lines if line.strip()])

        elements = soup.select('img[src*="role"]')
        roles = []
        for element in elements:
            line = str(element)
            roles.append(line)
        pattern = re.compile(r'\b(TOP|JUNGLE|MID|ADC|SUPPORT)\b')
        roles = [', '.join(pattern.findall(s)) for s in roles]

        elements = str(soup)
        pattern = r'<td class="text-center">(.*?)</td>'
        elements = re.findall(pattern, elements)
        elements = [s for i, s in enumerate(elements) if (len(s) <= 6)]
        elements = elements[3:]
        KDA = elements[::3]
        VSPM = elements[2::3]

        tables = soup.find('table', {'class': 'table_list footable toggle-square-filled'})
        trs = tables.find_all('tr')
        divs = [div for tr in trs for div in tr.find_all('div')]
        elements = divs[2::3]
        games = []
        for index, td in enumerate(elements, start=1):
            games.append(td.get_text())
        games = [re.findall(r'(?:(?<=\n\n\s{7})|\b)(\d+)(?=\n\n|$)', s) for s in games]
        games = [sum(map(int, lista)) for lista in games]

        elements = soup.select('img[src*="img/pays"]')
        countries = []
        for element in elements:
            line = str(element)
            countries.append(line)
        countries = [re.findall(r'img alt="([^"]+)"', s) for s in countries]
        countries = sum(countries, [])
        countries = coco.convert(names=countries, to='name_short')

        lines = team_stats.split('\n')

        team_name = lines[0][:-6]
        season = lines[5]
        win_rate = float(lines[8].replace('%',''))/100
        team_games = lines[7]
        numbers = numbers = re.findall(r'\d+', team_games)
        team_games = sum(int(num) for num in numbers)

        try:
            player_info = pd.DataFrame({'Players': player_names, 'Roles': roles, 'KDA': KDA, 'VSPM': VSPM, 'N_games': games, 'Country': countries})
            player_info = player_info.sort_values(by='N_games', ascending=False)
            player_info = player_info.head(5)
        except:
            return None

        player_count = {}

        player_info['Players'] = player_info['Players'].apply(lambda player: f"{player}_{player_count.setdefault(player, 0) + 1}" if player in player_count else player_count.update({player: 1}) or player)
        player_info.reset_index(drop=True, inplace=True)

        row_names = ['Season', 'Win rate', 'Games']

        for player in range(len(player_info)):
            row_names.append(f'Player {player+1}')

        for player in range(len(player_info)):
            row_names.append(f'Player {player+1} role')

        for player in range(len(player_info)):
            row_names.append(f'Player {player+1} KDA')

        for player in range(len(player_info)):
            row_names.append(f'Player {player+1} VSPM')

        for player in range(len(player_info)):
            row_names.append(f'Player {player+1} games')  

        for player in range(len(player_info)):
            row_names.append(f'Player {player+1} country') 

        df = pd.DataFrame(index=row_names, columns=[team_name])
        df.loc['Season'] = season
        df.loc['Win rate'] = win_rate
        df.loc['Games'] = team_games

        for player in range(len(player_info)):
            df.loc[f'Player {player+1}'] = player_info['Players'][player]

        for player in range(len(player_info)):
            df.loc[f'Player {player+1} role'] = player_info['Roles'][player]

        for player in range(len(player_info)):
            df.loc[f'Player {player+1} KDA'] = player_info['KDA'][player]

        for player in range(len(player_info)):
            df.loc[f'Player {player+1} VSPM'] = player_info['VSPM'][player]

        for player in range(len(player_info)):
            df.loc[f'Player {player+1} games'] = player_info['N_games'][player]

        for player in range(len(player_info)):
            df.loc[f'Player {player+1} country'] = player_info['Country'][player]

        return df
    
    else:
        print("Whoopsie")
        return None

# %%
#Scraping pipeline - creates a concatenated dataframe of selected teams in given seasons based on their team-season ID and saves it to .csv.

seasons = []
for season in range(8, 14):
    seasons.append(str(season))

all_IDs = []
for season in seasons:
    IDs = get_lol_team_id(season)
    all_IDs.extend(IDs)
    
data = pd.DataFrame()
for ID in all_IDs:
    df = get_lol_team_info(ID)
    data = pd.concat([data, df], axis=1, sort=False)
    data.to_csv('lol_data.csv', index=True)

# %%
data.shape
# Out:
# (33, 727)

# %%
data
# Out:
#                     100 Thieves Afreeca Freecs Detonation FocusMe
# Season                       S8             S8                 S8  \
# Win rate                   0.54           0.59               0.72
# Games                        69            121                 61
# Player 1               Aphromoo          TusiN                Evi
# Player 2                ssumday           Kiin              Steal
# Player 3                    Ryu           kurO              viviD
# Player 4               Cody Sun         Spirit              Ceros
# Player 5                 Meteos         Kramer            Yutapon
# Player 1 role           SUPPORT        SUPPORT                TOP
# Player 2 role               TOP            TOP             JUNGLE
# Player 3 role               MID            MID            SUPPORT
# Player 4 role               ADC         JUNGLE                MID
# Player 5 role            JUNGLE            ADC                ADC
# Player 1 KDA                  3            3.6                3.6
# Player 2 KDA                4.2            3.9                4.5
# Player 3 KDA                3.4            4.6                4.5
# Player 4 KDA                5.6            3.8                  5
# Player 5 KDA                3.4            5.3                6.5
# Player 1 VSPM               2.2           2.61               1.05
# Player 2 VSPM              1.25           1.24               2.28
# Player 3 VSPM              1.28           1.47               2.31
# Player 4 VSPM              1.15           2.67               1.07
# Player 5 VSPM              2.21           1.63               0.89
# Player 1 games               69            121                 61
# Player 2 games               65            119                 61
# Player 3 games               64            118                 61
# Player 4 games               53             90                 59
# Player 5 games               31             75                 59
# Player 1 country  United States    South Korea              Japan
# Player 2 country    South Korea    South Korea        South Korea
# Player 3 country    South Korea    South Korea        South Korea
# Player 4 country         Canada    South Korea              Japan
# Player 5 country  United States    South Korea              Japan
#
#                   Dire Wolves FC Schalke 04     Fnatic   G2 Esports
# Season                     S8            S8         S8           S8  \
# Win rate                 0.74          0.51       0.69         0.58
# Games                      72            55         87           86
# Player 1               Triple    Vizicsacsi  Hylissang       Wunder
# Player 2                 k1ng      Nukeduck     Broxah      Hjarnan
# Player 3              Cupcake         Upset       Caps        Wadid
# Player 4            Shernfire        VandeR    Rekkles       Jankos
# Player 5           BioPanther       Amazing       sOAZ        Perkz
# Player 1 role             MID           TOP    SUPPORT          TOP
# Player 2 role             ADC           MID     JUNGLE          ADC
# Player 3 role         SUPPORT           ADC        MID      SUPPORT
# Player 4 role          JUNGLE       SUPPORT        ADC       JUNGLE
# Player 5 role             TOP        JUNGLE        TOP          MID
# Player 1 KDA              5.6           2.3        3.1            4
# Player 2 KDA              5.1           3.3        6.6          5.3
# Player 3 KDA              4.8           5.2        3.7          3.9
# Player 4 KDA              3.5           3.7        8.3          4.4
# Player 5 KDA              4.8           2.9        3.4          3.7
# Player 1 VSPM            1.12          1.16       2.09         1.15
# Player 2 VSPM            1.16          1.04       1.77         1.11
# Player 3 VSPM            2.25          1.46       1.17         2.49
# Player 4 VSPM             1.9          2.35        1.3         2.25
# Player 5 VSPM             1.1          1.69       1.04         1.12
# Player 1 games             72            55         87           86
# Player 2 games             72            53         86           86
# Player 3 games             72            53         86           86
# Player 4 games             65            53         69           79
# Player 5 games             37            35         45           79
# Player 1 country    Australia       Hungary   Bulgaria      Denmark
# Player 2 country    Australia        Norway    Denmark       Sweden
# Player 3 country  New Zealand       Germany    Denmark  South Korea
# Player 4 country    Australia        Poland     Sweden       Poland
# Player 5 country    Australia       Germany     France      Croatia
#
#                  Isurus Gaming Jin Air Green Wings Kaos Latin Gamers  ...
# Season                      S8                  S8                S8  ...  \
# Win rate                  0.66                0.39               0.7  ...
# Games                       56                  97                76  ...
# Player 1                    QQ              SoHwan              Nate  ...
# Player 2              Kindless               Teddy              Slow  ...
# Player 3                Newbie                UmTi          Tierwulf  ...
# Player 4                   Emp               Grace               Fix  ...
# Player 5                Buggax                Nova             Plugo  ...
# Player 1 role           JUNGLE                 TOP               TOP  ...
# Player 2 role              ADC                 ADC           SUPPORT  ...
# Player 3 role          SUPPORT              JUNGLE            JUNGLE  ...
# Player 4 role              MID                 MID               ADC  ...
# Player 5 role              TOP             SUPPORT               MID  ...
# Player 1 KDA               3.8                   3               4.3  ...
# Player 2 KDA               5.1                 4.3               4.2  ...
# Player 3 KDA               6.6                 2.8               3.3  ...
# Player 4 KDA               7.7                 3.3               4.5  ...
# Player 5 KDA               3.5                 2.3               5.6  ...
# Player 1 VSPM             2.04                1.19              1.09  ...
# Player 2 VSPM             1.31                1.33              2.37  ...
# Player 3 VSPM              2.6                2.72              1.94  ...
# Player 4 VSPM             1.41                1.02              1.22  ...
# Player 5 VSPM             0.91                2.69              1.41  ...
# Player 1 games              56                  97                75  ...
# Player 2 games              56                  97                74  ...
# Player 3 games              56                  93                73  ...
# Player 4 games              54                  80                73  ...
# Player 5 games              29                  45                71  ...
# Player 1 country         Chile         South Korea         Argentina  ...
# Player 2 country         Chile         South Korea             Chile  ...
# Player 3 country     Argentina         South Korea             Chile  ...
# Player 4 country         Chile         South Korea         Argentina  ...
# Player 5 country       Uruguay         South Korea             Chile  ...
#
#                  ViV Esport Vivo Keyd Stars Vivo Keyd Stars Academy
# Season                  S13             S13                     S13  \
# Win rate               0.46            0.42                    0.63
# Games                    41              45                      64
# Player 1             XERSUS           Guigo                   Tyrin
# Player 2             Joinze        Grevthar                   Sting
# Player 3           Serendip           Grell                  Leleko
# Player 4             Twelve           Trigo                   Telas
# Player 5            Caliste          Damage                   ST3PZ
# Player 1 role       SUPPORT             TOP                     TOP
# Player 2 role        JUNGLE             MID                  JUNGLE
# Player 3 role           MID          JUNGLE                     MID
# Player 4 role           TOP             ADC                 SUPPORT
# Player 5 role           ADC         SUPPORT                     ADC
# Player 1 KDA            3.4             2.2                     4.7
# Player 2 KDA              3             4.3                     4.1
# Player 3 KDA            2.9             3.5                       4
# Player 4 KDA            3.6             5.6                     4.8
# Player 5 KDA            3.5             2.9                     4.9
# Player 1 VSPM          2.85            1.16                    1.07
# Player 2 VSPM           1.3            1.26                    1.52
# Player 3 VSPM          1.27            1.43                    1.25
# Player 4 VSPM          0.86            1.32                    3.13
# Player 5 VSPM          1.18            3.22                    1.27
# Player 1 games           35              45                      64
# Player 2 games           34              45                      62
# Player 3 games           34              37                      58
# Player 4 games           33              27                      43
# Player 5 games           22              27                      33
# Player 1 country     France          Brazil                  Brazil
# Player 2 country     France          Brazil                  Brazil
# Player 3 country     France          Mexico                  Brazil
# Player 4 country     France          Brazil                  Brazil
# Player 5 country     France          Brazil                  Brazil
#
#                  Weibo Gaming White Dragons Wildcard Gaming Wizards Club
# Season                    S13           S13             S13          S13  \
# Win rate                 0.61          0.48            0.55         0.62
# Games                     118            63              84           77
# Player 1               TheShy        Caucha            Keel       DahVys
# Player 2               xiaohu         Worst          Soligo   IceBreaker
# Player 3                Light          D4SH            Lens   Tsiperakos
# Player 4                Crisp          Noma        Duoking1        Simpy
# Player 5               WeiWei       Calmsky          Zamudo    Lindgarde
# Player 1 role             TOP           TOP          JUNGLE       JUNGLE
# Player 2 role             MID           ADC             MID          TOP
# Player 3 role             ADC        JUNGLE             ADC          MID
# Player 4 role         SUPPORT           MID         SUPPORT      SUPPORT
# Player 5 role          JUNGLE       SUPPORT             TOP          ADC
# Player 1 KDA              2.3           2.4             3.6          4.2
# Player 2 KDA              4.1           4.5             3.5          3.1
# Player 3 KDA              6.5           3.1             3.9          5.2
# Player 4 KDA              4.3           3.1             2.8          4.3
# Player 5 KDA                4           2.8             2.4          5.1
# Player 1 VSPM            1.02          0.97            1.25         1.43
# Player 2 VSPM             1.2          0.93            1.06         0.91
# Player 3 VSPM            1.07          1.43            0.88          1.3
# Player 4 VSPM             3.5          1.29            2.59         2.95
# Player 5 VSPM            1.47          2.89            0.77         0.89
# Player 1 games            118            62              84           77
# Player 2 games            118            62              84           76
# Player 3 games            117            61              84           76
# Player 4 games            117            61              47           75
# Player 5 games             76            54              43           43
# Player 1 country  South Korea      Portugal   United States        Spain
# Player 2 country        China      Portugal   United States       Greece
# Player 3 country        China      Portugal         Türkiye       Greece
# Player 4 country        China      Portugal          Canada        Spain
# Player 5 country        China      Portugal          Canada       Sweden
#
#                  WLGaming Esports Zero Tenacity     ZETA
# Season                        S13           S13      S13
# Win rate                     0.65          0.72     0.47
# Games                          68            60       45
# Player 1                  Bruness         Color   kaylem
# Player 2                Bananitoo       Ryuzaki      Nyx
# Player 3                 HeSSZero        Kabbie    mihai
# Player 4                    Vladi         SlowQ   Bolyy1
# Player 5                   Jeyrus          Noah    J0J0C
# Player 1 role              JUNGLE           TOP      TOP
# Player 2 role             SUPPORT        JUNGLE   JUNGLE
# Player 3 role                 TOP       SUPPORT      ADC
# Player 4 role                 MID           MID  SUPPORT
# Player 5 role                 ADC           ADC      MID
# Player 1 KDA                  4.8           3.3      2.6
# Player 2 KDA                  3.5           5.9      3.1
# Player 3 KDA                  3.8           5.1      4.3
# Player 4 KDA                  4.1           4.5        3
# Player 5 KDA                  7.2           5.4      2.5
# Player 1 VSPM                1.35          0.95     0.96
# Player 2 VSPM                 2.7          1.31     1.33
# Player 3 VSPM                0.97          2.91     1.02
# Player 4 VSPM                1.16          1.18     2.94
# Player 5 VSPM                1.35          1.33     1.03
# Player 1 games                 68            60       45
# Player 2 games                 68            60       45
# Player 3 games                 35            60       45
# Player 4 games                 35            52       45
# Player 5 games                 35            33       22
# Player 1 country           Poland        Poland  Romania
# Player 2 country           Greece        Serbia    Spain
# Player 3 country           Poland   South Korea  Romania
# Player 4 country           Greece   South Korea    Spain
# Player 5 country          Türkiye   South Korea   Greece
#
# [33 rows x 727 columns]

# %%
data.to_csv('lol_data.csv', index=True)
